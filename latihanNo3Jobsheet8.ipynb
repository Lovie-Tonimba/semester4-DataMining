# %% [markdown]
# <a href="https://colab.research.google.com/github/Lovie-Tonimba/semester4-DataMining/blob/main/latihanNo3Jobsheet8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
X = iris.data[:, [0, 1]] # ambil 2 fitur (Sepal Length & Width)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

dbscan = DBSCAN(eps=0.4, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='viridis')
plt.title("Hasil DBSCAN Clustering (Data Iris)")
plt.xlabel("Sepal Length (Standardized)")
plt.ylabel("Sepal Width (Standardized)")
plt.grid(True)
plt.show()
